# %% [markdown]
# # Problemas de Estadística Descriptiva
#
# ## Ejercicio 1 – ¿Qué tan largos son los títulos de las películas?
#
# En este ejercicio vas a aplicar técnicas de estadística descriptiva sobre un conjunto de datos real: una base con 1000 películas populares del sitio IMDb.
#
# A partir del título de cada película, vas a:
# - Calcular la longitud del título (en caracteres).
# - Obtener métricas estadísticas clave: media, mediana, moda, rango, varianza, desviación estándar, asimetría y curtosis.
# - Identificar los títulos más largos y más cortos.
# - Visualizar la distribución de estas longitudes con un histograma y una curva de densidad.

# %%
# Importar librerias
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis, mode

# Cargar dataset de IMDb
url = "../assets/imdb_1000.csv"
df = pd.read_csv(url)
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
df["title_length"] = df["title"].apply(len) #creamos una columnanueva la cual va a contar con .apply(len) cada letra del titulo no solo columnas q seria len 
df[["title", "title_length"]].head()
# Out:
#                       title  title_length
# 0  The Shawshank Redemption            24
# 1             The Godfather            13
# 2    The Godfather: Part II            22
# 3           The Dark Knight            15
# 4              Pulp Fiction            12

# %%
df["title_length"].mean()
# Out:
# np.float64(15.481103166496425)

# %%
df["title_length"].median()
# Out:
# np.float64(14.0)

# %%
df["title_length"].mode()
# Out:
# 0    12
# Name: title_length, dtype: int64

# %%
df["title_length"].max() - df["title_length"].min()  # Calcula el rango de la columna 'title_length'
# Out:
# np.int64(67)

# %%
df["title_length"].var()  # Calcula la varianza de la columna 'title_length'
# Out:
# np.float64(72.1067488840288)

# %%
df["title_length"].std()  # Calcula la desviación estándar de la columna 'title_length'
# Out:
# np.float64(8.491569282766807)

# %%
df["title_length"].skew()  # Calcula la asimetría de la columna 'title_length'
# Out:
# np.float64(1.5252523464631278)

# %%
df["title_length"].kurt()  # Calcula la curtosis de la columna 'title_length'
# Out:
# np.float64(3.8122887061291544)

# %%
df["title_length"].hist()  # histograma de la columna 'title_length'
# Out:
# <Axes: >

# %% [markdown]
# ---
#
# ## Ejercicio 2 – Cálculo manual de desviación estándar
#
# En este ejercicio vas a calcular manualmente la desviación estándar, seleccionando cinco títulos reales del dataset de películas que cargaste antes.

# %%
title_length = [24, 13, 22, 15, 12]# Crea una lista con 5 valores reales de df['title_length'], por ejemplo: [10, 13, 14, 18, 22]

# %%
media = sum(title_length) / len(title_length)  # Calcula la media manual de la lista 'title_length'# Calcula la media de los 5 valores
media
# Out:
# 17.2

# %%
diferencias_cuadrado = [(x - media) ** 2 for x in title_length] # Calcula las diferencias al cuadrado con respecto a la media
diferencias_cuadrado
# Out:
# [46.24000000000001,
#  17.639999999999993,
#  23.040000000000006,
#  4.839999999999997,
#  27.039999999999992]

# %% [markdown]
# el analisis de los datos lo que me hizo ver es q a pesar de que existen muy pococ titulos largos hacer q la media aumente por eso hay q seguir analizando. si miras pocos datos estas acabado .
